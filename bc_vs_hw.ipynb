# %%
# !pip install xarray netCDF4
! pip install matplotlib seaborn
# Out:
# Requirement already satisfied: xarray in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (2025.6.1)
# Requirement already satisfied: netCDF4 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (1.7.4)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from xarray) (2.2.5)
# Requirement already satisfied: packaging>=23.2 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from xarray) (25.0)
# Requirement already satisfied: pandas>=2.1 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from xarray) (2.3.3)
# Requirement already satisfied: cftime in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from netCDF4) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from pandas>=2.1->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from pandas>=2.1->xarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from pandas>=2.1->xarray) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray) (1.17.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from scikit-learn) (2.2.5)
# Requirement already satisfied: scipy>=1.8.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from scikit-learn) (3.6.0)

# %%
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting accelerate==1.10.1 (from -r requirements.txt (line 1))
#   Using cached accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting aiofiles==25.1.0 (from -r requirements.txt (line 2))
#   Using cached aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting aiohappyeyeballs==2.6.1 (from -r requirements.txt (line 3))
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.10.11 (from -r requirements.txt (line 4))
#   Using cached aiohttp-3.10.11-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting aiohttp-retry==2.8.3 (from -r requirements.txt (line 5))
#   Using cached aiohttp_retry-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Collecting aioice==0.10.1 (from -r requirements.txt (line 6))
#   Using cached aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting aiortc==1.14.0 (from -r requirements.txt (line 7))
#   Using cached aiortc-1.14.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting aiosignal==1.4.0 (from -r requirements.txt (line 8))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting aiosqlite==0.21.0 (from -r requirements.txt (line 9))
#   Using cached aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting albucore==0.0.33 (from -r requirements.txt (line 10))
#   Using cached albucore-0.0.33-py3-none-any.whl.metadata (7.8 kB)
# Collecting albumentationsx==2.0.11 (from -r requirements.txt (line 11))
#   Using cached albumentationsx-2.0.11-py3-none-any.whl.metadata (79 kB)
# Collecting annotated-types==0.7.0 (from -r requirements.txt (line 12))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting anthropic==0.49.0 (from -r requirements.txt (line 13))
#   Using cached anthropic-0.49.0-py3-none-any.whl.metadata (24 kB)
# Collecting anyio==4.11.0 (from -r requirements.txt (line 14))
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting anywidget==0.9.18 (from -r requirements.txt (line 15))
#   Using cached anywidget-0.9.18-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: appnope==0.1.4 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.1.4)
# Collecting APScheduler==3.11.0 (from -r requirements.txt (line 17))
#   Using cached APScheduler-3.11.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting asttokens==2.4.1 (from -r requirements.txt (line 18))
#   Using cached asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting asyncua==1.1.8 (from -r requirements.txt (line 19))
#   Using cached asyncua-1.1.8-py3-none-any.whl.metadata (9.6 kB)
# Collecting attrs==25.3.0 (from -r requirements.txt (line 20))
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting av==16.0.1 (from -r requirements.txt (line 21))
#   Using cached av-16.0.1-cp310-cp310-macosx_14_0_arm64.whl.metadata (4.6 kB)
# Collecting azure-core==1.35.0 (from -r requirements.txt (line 22))
#   Using cached azure_core-1.35.0-py3-none-any.whl.metadata (44 kB)
# Collecting azure-identity==1.23.1 (from -r requirements.txt (line 23))
#   Using cached azure_identity-1.23.1-py3-none-any.whl.metadata (82 kB)
# Collecting backoff==2.2.1 (from -r requirements.txt (line 24))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting bbox_visualizer==0.2.2 (from -r requirements.txt (line 25))
#   Using cached bbox_visualizer-0.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting bcrypt==5.0.0 (from -r requirements.txt (line 26))
#   Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting boto3==1.35.60 (from -r requirements.txt (line 27))
#   Using cached boto3-1.35.60-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore==1.35.99 (from -r requirements.txt (line 28))
#   Using cached botocore-1.35.99-py3-none-any.whl.metadata (5.7 kB)
# Collecting brambox==5.0.0 (from -r requirements.txt (line 29))
#   Using cached brambox-5.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Collecting cachetools==5.5.2 (from -r requirements.txt (line 30))
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting certifi==2024.12.14 (from -r requirements.txt (line 31))
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting cffi==2.0.0 (from -r requirements.txt (line 32))
#   Using cached cffi-2.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting charset-normalizer==3.4.1 (from -r requirements.txt (line 33))
#   Using cached charset_normalizer-3.4.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting click==8.1.8 (from -r requirements.txt (line 34))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting coloredlogs==15.0.1 (from -r requirements.txt (line 35))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting comm==0.2.2 (from -r requirements.txt (line 36))
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy==1.3.1 (from -r requirements.txt (line 37))
#   Using cached contourpy-1.3.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cryptography==46.0.2 (from -r requirements.txt (line 38))
#   Using cached cryptography-46.0.2-cp38-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: cycler==0.12.1 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.12.1)
# Collecting Cython==3.0.12 (from -r requirements.txt (line 40))
#   Using cached Cython-3.0.12-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting dataclasses-json==0.6.7 (from -r requirements.txt (line 41))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting debugpy==1.8.8 (from -r requirements.txt (line 42))
#   Using cached debugpy-1.8.8-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r requirements.txt (line 43))
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting defusedxml==0.7.1 (from -r requirements.txt (line 44))
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting distro==1.9.0 (from -r requirements.txt (line 45))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting dnspython==2.8.0 (from -r requirements.txt (line 46))
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting docker==7.1.0 (from -r requirements.txt (line 47))
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dotenv==0.9.9 (from -r requirements.txt (line 48))
#   Using cached dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting einops==0.8.1 (from -r requirements.txt (line 49))
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting executing==2.1.0 (from -r requirements.txt (line 50))
#   Using cached executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting fairscale==0.4.13 (from -r requirements.txt (line 51))
#   Using cached fairscale-0.4.13.tar.gz (266 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi==0.115.14 (from -r requirements.txt (line 52))
#   Using cached fastapi-0.115.14-py3-none-any.whl.metadata (27 kB)
# Collecting fastjsonschema==2.21.1 (from -r requirements.txt (line 53))
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting filelock==3.17.0 (from -r requirements.txt (line 54))
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting filetype==1.2.0 (from -r requirements.txt (line 55))
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting flatbuffers==25.9.23 (from -r requirements.txt (line 56))
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting fonttools==4.55.3 (from -r requirements.txt (line 57))
#   Using cached fonttools-4.55.3-cp310-cp310-macosx_10_9_universal2.whl.metadata (165 kB)
# Collecting frozenlist==1.8.0 (from -r requirements.txt (line 58))
#   Using cached frozenlist-1.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting fsspec==2025.9.0 (from -r requirements.txt (line 59))
#   Using cached fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting ftfy==6.3.1 (from -r requirements.txt (line 60))
#   Using cached ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting google-api-core==2.28.1 (from -r requirements.txt (line 61))
#   Using cached google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-auth==2.43.0 (from -r requirements.txt (line 62))
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-cloud==0.34.0 (from -r requirements.txt (line 63))
#   Using cached google_cloud-0.34.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-dialogflow-cx==2.0.0 (from -r requirements.txt (line 64))
#   Using cached google_cloud_dialogflow_cx-2.0.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting google-crc32c==1.7.1 (from -r requirements.txt (line 65))
#   Using cached google_crc32c-1.7.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (2.3 kB)
# Collecting googleapis-common-protos==1.72.0 (from -r requirements.txt (line 66))
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting grpcio==1.76.0 (from -r requirements.txt (line 67))
#   Using cached grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting grpcio-status==1.76.0 (from -r requirements.txt (line 68))
#   Using cached grpcio_status-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting h11==0.16.0 (from -r requirements.txt (line 69))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting helpers==0.2.0 (from -r requirements.txt (line 70))
#   Using cached helpers-0.2.0-py3-none-any.whl.metadata (708 bytes)
# Collecting hf-xet==1.1.10 (from -r requirements.txt (line 71))
#   Using cached hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Collecting httpcore==1.0.9 (from -r requirements.txt (line 72))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting httpx==0.28.1 (from -r requirements.txt (line 73))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub==0.35.3 (from -r requirements.txt (line 74))
#   Using cached huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting humanfriendly==10.0 (from -r requirements.txt (line 75))
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting idna==3.7 (from -r requirements.txt (line 76))
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting ifaddr==0.2.0 (from -r requirements.txt (line 77))
#   Using cached ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: imageio==2.37.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 78)) (2.37.0)
# Collecting inference==0.58.2 (from -r requirements.txt (line 79))
#   Using cached inference-0.58.2-py3-none-any.whl.metadata (24 kB)
# Collecting iniconfig==2.0.0 (from -r requirements.txt (line 80))
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting invoke==2.2.1 (from -r requirements.txt (line 81))
#   Using cached invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 82))
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.29.0 (from -r requirements.txt (line 83))
#   Using cached ipython-8.29.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting ipywidgets==8.1.7 (from -r requirements.txt (line 84))
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting isodate==0.7.2 (from -r requirements.txt (line 85))
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jedi==0.19.2 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 86)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 87)) (3.1.6)
# Collecting jiter==0.11.0 (from -r requirements.txt (line 88))
#   Using cached jiter-0.11.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting jmespath==1.0.1 (from -r requirements.txt (line 89))
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting joblib==1.5.2 (from -r requirements.txt (line 90))
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting jpype1==1.5.1 (from -r requirements.txt (line 91))
#   Using cached jpype1-1.5.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting jsonschema==4.25.0 (from -r requirements.txt (line 92))
#   Using cached jsonschema-4.25.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting jsonschema-specifications==2025.4.1 (from -r requirements.txt (line 93))
#   Using cached jsonschema_specifications-2025.4.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting jupyter_bbox_widget==0.6.0 (from -r requirements.txt (line 94))
#   Using cached jupyter_bbox_widget-0.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jupyter_client==8.6.3 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 95)) (8.6.3)
# Collecting jupyter_core==5.7.2 (from -r requirements.txt (line 96))
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting jupyterlab_widgets==3.0.15 (from -r requirements.txt (line 97))
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting kiwisolver==1.4.8 (from -r requirements.txt (line 98))
#   Using cached kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting lazy_loader==0.4 (from -r requirements.txt (line 99))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting lxml==6.0.2 (from -r requirements.txt (line 100))
#   Using cached lxml-6.0.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting markdown-it-py==4.0.0 (from -r requirements.txt (line 101))
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: MarkupSafe==3.0.3 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 102)) (3.0.3)
# Collecting marshmallow==3.26.1 (from -r requirements.txt (line 103))
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting matplotlib==3.10.0 (from -r requirements.txt (line 104))
#   Using cached matplotlib-3.10.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 105)) (0.1.7)
# Collecting mdurl==0.1.2 (from -r requirements.txt (line 106))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: mpmath==1.3.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 107)) (1.3.0)
# Collecting msal==1.33.0 (from -r requirements.txt (line 108))
#   Using cached msal-1.33.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions==1.3.1 (from -r requirements.txt (line 109))
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting multidict==6.7.0 (from -r requirements.txt (line 110))
#   Using cached multidict-6.7.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting mypy_extensions==1.1.0 (from -r requirements.txt (line 111))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting nbformat==5.10.4 (from -r requirements.txt (line 112))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /opt/anaconda3/envs/aml_py310/lib/python3.10/site-packages (from -r requirements.txt (line 113)) (1.6.0)
# ERROR: Ignored the following yanked versions: 2.6, 2.6.1
# ERROR: Ignored the following versions that require a different python version: 1.3.3 Requires-Python >=3.11; 3.5 Requires-Python >=3.11; 3.5rc0 Requires-Python >=3.11; 3.6 Requires-Python >=3.11; 3.6.1 Requires-Python >=3.11,!=3.14.1; 3.6rc0 Requires-Python >=3.11; 9.0.0 Requires-Python >=3.11; 9.0.0b1 Requires-Python >=3.11; 9.0.0b2 Requires-Python >=3.11; 9.0.1 Requires-Python >=3.11; 9.0.2 Requires-Python >=3.11; 9.1.0 Requires-Python >=3.11; 9.10.0 Requires-Python >=3.11; 9.11.0 Requires-Python >=3.12; 9.2.0 Requires-Python >=3.11; 9.3.0 Requires-Python >=3.11; 9.4.0 Requires-Python >=3.11; 9.5.0 Requires-Python >=3.11; 9.6.0 Requires-Python >=3.11; 9.7.0 Requires-Python >=3.11; 9.8.0 Requires-Python >=3.11; 9.9.0 Requires-Python >=3.11
# ERROR: Could not find a version that satisfies the requirement networkx==3.5 (from versions: 0.34, 0.35, 0.35.1, 0.36, 0.37, 0.99, 1.0rc1, 1.0, 1.0.1, 1.1, 1.2rc1, 1.2, 1.3rc1, 1.3, 1.4rc1, 1.4, 1.5rc1, 1.5, 1.6rc1, 1.6, 1.7rc1, 1.7, 1.8rc1, 1.8, 1.8.1, 1.9rc1, 1.9, 1.9.1, 1.10rc2, 1.10, 1.11rc1, 1.11rc2, 1.11, 2.0, 2.1, 2.2rc1, 2.2, 2.3rc3, 2.3rc4, 2.3, 2.4rc1, 2.4rc2, 2.4, 2.5rc1, 2.5, 2.5.1, 2.6rc1, 2.6rc2, 2.6.2, 2.6.3, 2.7rc1, 2.7, 2.7.1, 2.8rc1, 2.8, 2.8.1rc1, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.8.5, 2.8.6, 2.8.7, 2.8.8, 3.0b1, 3.0rc1, 3.0, 3.1rc0, 3.1, 3.2rc0, 3.2, 3.2.1, 3.3rc0, 3.3, 3.4rc0, 3.4, 3.4.1, 3.4.2)
# ERROR: No matching distribution found for networkx==3.5

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.metrics import (
    f1_score, precision_score, recall_score, roc_auc_score,
    average_precision_score
)
import os
import imageio.v2 as imageio
from datetime import datetime, timedelta
from scipy import ndimage

# %%
clean_ds = xr.open_dataset("clean_complex_network_dataset.nc")
print(clean_ds)
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:      (lon: 268, lat: 141, time: 2790)
# Coordinates:
#   * lon          (lon) float32 1kB -26.0 -25.75 -25.5 -25.25 ... 40.5 40.75 41.0
#   * lat          (lat) float32 564B 35.8 36.05 36.3 36.55 ... 70.5 70.75 71.0
#   * time         (time) datetime64[ns] 22kB 1990-06-01 1990-06-02 ... 2020-08-31
# Data variables:
#     DC           (time, lat, lon) float32 422MB ...
#     CC           (time, lat, lon) float32 422MB ...
#     BC           (time, lat, lon) float32 422MB ...
#     ID           (time, lat, lon) float32 422MB ...
#     OD           (time, lat, lon) float32 422MB ...
#     is_heatwave  (time, lat, lon) float32 422MB ...

# %% [markdown]
# ## Build X and next-day target Y - choose COEFFICIENTS AND TARGET

# %%
def choose_coefficients_and_target(ds, coeffs, target):
    return xr.concat([ds[coeff] for coeff in coeffs], dim="channel").assign_coords(channel=list(coeffs)), ds[target]

COEFFS = ["CC", "DC", "ID", "OD", "is_heatwave"]  # change this list to include the coefficients you want to use as input features (e.g. if you want to predict CC, you can remove it from the input features and only keep it as target)
TARGET = "BC"  # change this to the target variable you want to predict (e.g. if you want to do regression and predict CC, change this to "CC")
TASK_TYPE = "regression"  # or "binary" or "CC_regression" 

# X coefficients at time t
X, y = choose_coefficients_and_target(clean_ds, COEFFS, TARGET)

# target y at time t+1
y = y.shift(time=-1)

# drop last time step (because y(t+1) missing at end)
X = X.isel(time=slice(None, -1))
y = y.isel(time=slice(None, -1))

print("X:", X.dims, X.shape)   
print("y:", y.dims, y.shape)
print("channels:", [str(c) for c in X.channel.values])
# Out:
# X: ('channel', 'time', 'lat', 'lon') (5, 2789, 141, 268)
# y: ('time', 'lat', 'lon') (2789, 141, 268)
# channels: ['CC', 'DC', 'ID', 'OD', 'is_heatwave']

# %% [markdown]
# ## Adjust to the Iberia region

# %%
# Iberia bounding box 
lon_min, lon_max = -10, 4
lat_min, lat_max = 36, 44

# %% [markdown]
# ## Adjust to the Mediterranean basin

# %%
# lon_min, lon_max = -10, 40
# lat_min, lat_max = 30, 48

# %%
X_ib = X.sel(lon=slice(lon_min, lon_max), lat=slice(lat_min, lat_max))
y_ib = y.sel(lon=slice(lon_min, lon_max), lat=slice(lat_min, lat_max))

print("X_ib:", X_ib.shape, X_ib.dims)
print("y_ib:", y_ib.shape, y_ib.dims)
# Out:
# X_ib: (5, 2789, 32, 56) ('channel', 'time', 'lat', 'lon')
# y_ib: (2789, 32, 56) ('time', 'lat', 'lon')

# %% [markdown]
# ## Use the range 1990-2003

# %%
X_0103 = X_ib.sel(time=slice("1990-06-01", "2003-08-31"))
y_0103 = y_ib.sel(time=slice("1990-06-01", "2003-08-31"))

print("Time range:", str(X_0103.time.values[0]), "→", str(X_0103.time.values[-1]))
# Out:
# Time range: 1990-06-01T00:00:00.000000000 → 2003-08-31T00:00:00.000000000

# %% [markdown]
# ## Yearly sequences

# %%
def make_sequences_per_year(X, y, seq_len=14):
    """
    X: (channel, time, lat, lon)
    y: (time, lat, lon)
    Returns:
      X_seq: (N, seq_len, C, H, W)
      y_seq: (N, 1, H, W)
      y_dates: (N,) numpy datetime64 array = date of the target day
    """
    # time-first arrays
    Xt = X.transpose("time", "channel", "lat", "lon")
    yt = y.transpose("time", "lat", "lon")

    years = np.unique(Xt.time.dt.year.values)
    X_list, y_list, d_list = [], [], []

    for yr in years:
        Xy = Xt.sel(time=str(yr))
        yy = yt.sel(time=str(yr))

        T = Xy.sizes["time"]
        if T <= seq_len:
            continue

        Xv = Xy.values  # (T, C, H, W)
        yv = yy.values  # (T, H, W)
        times = Xy.time.values

        for i in range(T - seq_len):
            X_list.append(Xv[i:i+seq_len])
            y_list.append(yv[i+seq_len])         # predict next day after the window
            d_list.append(times[i+seq_len])      # store target day timestamp

    X_seq = np.stack(X_list).astype(np.float32)          # (N, L, C, H, W)
    y_seq = np.stack(y_list).astype(np.float32)[:, None] # (N, 1, H, W)
    y_dates = np.array(d_list)

    return X_seq, y_seq, y_dates

seq_len = 14
X_seq, y_seq, y_dates = make_sequences_per_year(X_0103, y_0103, seq_len=seq_len)

print("X_seq:", X_seq.shape)
print("y_seq:", y_seq.shape)
print("Target dates:", y_dates[0], "→", y_dates[-1])
print("y unique (sample):", np.unique(y_seq[:1]))
# Out:
# X_seq: (1030, 14, 5, 32, 56)
# y_seq: (1030, 1, 32, 56)
# Target dates: 1990-06-15T00:00:00.000000000 → 2003-08-31T00:00:00.000000000
# y unique (sample): [0.]

# %%
y_dates_d = y_dates.astype("datetime64[D]")

train_mask = (y_dates_d >= np.datetime64("1990-06-01")) & (y_dates_d <= np.datetime64("2002-08-31"))
val_mask   = (y_dates_d >= np.datetime64("2003-06-01")) & (y_dates_d <= np.datetime64("2003-07-26"))
test_mask  = (y_dates_d >= np.datetime64("2003-07-27")) & (y_dates_d <= np.datetime64("2003-08-31"))

X_train, y_train = X_seq[train_mask], y_seq[train_mask]
X_val,   y_val   = X_seq[val_mask],   y_seq[val_mask]
X_test,  y_test  = X_seq[test_mask],  y_seq[test_mask]
test_dates = y_dates_d[test_mask]

print("Train:", X_train.shape, y_train.shape)
print("Val:  ", X_val.shape, y_val.shape)
print("Test: ", X_test.shape, y_test.shape)
print("Test dates:", test_dates[0], "→", test_dates[-1])
# Out:
# Train: (952, 14, 5, 32, 56) (952, 1, 32, 56)
# Val:   (42, 14, 5, 32, 56) (42, 1, 32, 56)
# Test:  (36, 14, 5, 32, 56) (36, 1, 32, 56)
# Test dates: 2003-07-27 → 2003-08-31

# %% [markdown]
# #### Final check after split (to ensure no NaN or inf values)

# %%
print("Raw NaN in X_train:", np.isnan(X_train).any(), "Inf:", np.isinf(X_train).any())
# Out:
# Raw NaN in X_train: False Inf: False

# %% [markdown]
# Test tensor (47, 14, 5, 32, 56):
# 47 different target days
# 14 day input window
# 5 channels
# Iberia grid 32x56

# %% [markdown]
# ### Split - Train: 1990–2002, Val: 2003-06-01 → 2003-07-26, Test: 2003-07-27 → 2003-08-31

# %%
def normalize_per_channel(X_train, X_val, X_test, eps=1e-6):
    mean = X_train.mean(axis=(0,1,3,4), keepdims=True)
    std  = X_train.std(axis=(0,1,3,4), keepdims=True)
    return ((X_train - mean) / (std + eps),
            (X_val   - mean) / (std + eps),
            (X_test  - mean) / (std + eps),
            mean, std)

X_train_n, X_val_n, X_test_n, mean, std = normalize_per_channel(X_train, X_val, X_test)

# %% [markdown]
# ## Preprocess targets depending on task

# %%
if TASK_TYPE == "binary":
    y_train_p = y_train.astype(np.float32)
    y_val_p   = y_val.astype(np.float32)
    y_test_p  = y_test.astype(np.float32)

elif TASK_TYPE == "CC_regression":
    y_train_p = y_train.astype(np.float32)
    y_val_p   = y_val.astype(np.float32)
    y_test_p  = y_test.astype(np.float32)

elif TASK_TYPE == "regression":   # ID / OD
    y_train_raw = y_train.copy()
    y_val_raw   = y_val.copy()
    y_test_raw  = y_test.copy()
    y_train_p = np.log1p(y_train_raw).astype(np.float32)
    y_val_p   = np.log1p(y_val_raw).astype(np.float32)
    y_test_p  = np.log1p(y_test_raw).astype(np.float32)

if TASK_TYPE == "binary":
    print("Heatwave fraction train/val/test:",
          float(y_train_p.mean()), float(y_val_p.mean()), float(y_test_p.mean()))
elif TASK_TYPE == "CC_regression":
    print("CC mean target train/val/test:",
          float(y_train_p.mean()), float(y_val_p.mean()), float(y_test_p.mean()))
elif TASK_TYPE == "regression":
    print("Log-transformed target mean train/val/test:",
          float(y_train_p.mean()), float(y_val_p.mean()), float(y_test_p.mean()))
# Out:
# Log-transformed target mean train/val/test: 3.038222473605856e-07 5.675609031641216e-07 1.7604720596864354e-06

# %% [markdown]
# ## Class imbalance

# %%
def analyze_regression_target(y, name="target", show_log=False):
    vals = y.ravel()

    print(f"--- {name} ---")
    print("Min:", float(vals.min()))
    print("Max:", float(vals.max()))
    print("Mean:", float(vals.mean()))
    print("Std:", float(vals.std()))
    print("Median:", float(np.median(vals)))

    num_zero = np.sum(vals == 0)
    num_nonzero = np.sum(vals > 0)

    print("Zero pixels:", int(num_zero))
    print("Non-zero pixels:", int(num_nonzero))
    print("Zero ratio:", num_zero / len(vals))
    print("Non-zero ratio:", num_nonzero / len(vals))

    plt.figure(figsize=(8,5))
    plt.hist(vals, bins=50)
    plt.title(f"Distribution of {name}")
    plt.xlabel(name)
    plt.ylabel("Frequency")
    plt.show()

    if show_log:
        plt.figure(figsize=(8,5))
        plt.hist(np.log1p(vals), bins=50)
        plt.title(f"Distribution of log1p({name})")
        plt.xlabel(f"log1p({name})")
        plt.ylabel("Frequency")
        plt.show()

# %%
import numpy as np

if TASK_TYPE == "binary":
    pos = float(y_train.sum())
    neg = float(y_train.size - y_train.sum())

    print("Positive pixels:", pos)
    print("Negative pixels:", neg)
    print("Positive ratio:", pos / (pos + neg))
    print("Negative ratio:", neg / (pos + neg))

    pos = y_train.sum()
    neg = y_train.size - pos

    plt.bar(["Negative", "Positive"], [neg, pos])
    plt.title("Class Distribution in Training Data")
    plt.ylabel("Number of Pixels")
    plt.show()

elif TASK_TYPE in ["regression", "CC_regression"]:
    analyze_regression_target(y_train, name=TARGET, show_log=True)
# Out:
# --- BC ---
# Min: 0.0
# Max: 9.999999747378752e-06
# Mean: 3.0382295790332137e-07
# Std: 1.1412179219405516e-06
# Median: 0.0
# Zero pixels: 1557445
# Non-zero pixels: 148539
# Zero ratio: 0.9129306019282714
# Non-zero ratio: 0.08706939807172868

# %% [markdown]
# # Pipeline - binary (is_heatwave) and non-binary (CC, ID, OD) target prediction

# %% [markdown]
# ## ConvLSTM

# %%
class NumpySeqDataset(Dataset):
    # wraps numpy arrays into a PyTorch Dataset for easy batching
    def __init__(self, X, y):
        self.X = torch.from_numpy(X).float()  # (N - samples, L - frames/time steps, C - number of channels per frame, H - height, W - width)
        self.y = torch.from_numpy(y).float()  # (N labels, 1, H, W) - target is heatwave next day (binary mask - Y/N)
    def __len__(self): return self.X.shape[0]
    def __getitem__(self, i): return self.X[i], self.y[i]

class ConvLSTMCell(nn.Module):
    # standard LSTM cell but with convolutional gates instead of linear (standard LSTM does fully connected gates, ConvLSTM does convolutional gates to preserve spatial structure)
    # we do it to keep the spatial relationships between neighboring cells 
    def __init__(self, input_dim, hidden_dim, kernel_size=3):
        super().__init__()
        padding = kernel_size // 2
        self.hidden_dim = hidden_dim
        self.conv = nn.Conv2d(input_dim + hidden_dim, 4 * hidden_dim,
                              kernel_size=kernel_size, padding=padding)
        # LSTM uses matrix multiplication to compute gates, we replace it with 2D convolution to preserve spatial structure, the hidden state remains a spatial feature map instead of collapsing space into a vector

    def forward(self, x, h, c):
        # x: (B, Cin, H, W), h/c: (B, Chid, H, W)
        combined = torch.cat([x, h], dim=1) # x and h are concatenated along the channel dimension to form the input to the convolutional gates 
        # x is the current input frame (with all channels), h is the previous hidden state (also a feature map), it carries information from previous time steps, by concatenating them we allow the gates to compute based on both current input and past hidden state
        gates = self.conv(combined)
        i, f, o, g = torch.chunk(gates, 4, dim=1)
        i = torch.sigmoid(i) # how much of new info to write into memory
        f = torch.sigmoid(f) # how much of old memory to keep
        o = torch.sigmoid(o) # how much of memory to expose as hidden state
        g = torch.tanh(g) # candidate new memory content
        c_next = f * c + i * g
        h_next = o * torch.tanh(c_next)
        return h_next, c_next

class ConvLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim=32, kernel_size=3):
        """
        task_type:
            - 'binary'        -> returns raw logits for BCEWithLogitsLoss
            - 'regression'    -> returns unbounded output for ID / OD prediction
            - 'CC_regression' -> returns sigmoid-bounded output in [0,1]
        """
        super().__init__()
        self.cell = ConvLSTMCell(input_dim, hidden_dim, kernel_size)
        self.head = nn.Conv2d(hidden_dim, 1, kernel_size=1)

        if TASK_TYPE not in ["binary", "regression", "CC_regression"]:
            raise ValueError("task_type must be 'binary' or 'regression' or 'CC_regression'")

    def forward(self, x):
        # x: (B, L, C, H, W)
        B, L, C, H, W = x.shape
        h = torch.zeros(B, self.cell.hidden_dim, H, W, device=x.device)
        c = torch.zeros(B, self.cell.hidden_dim, H, W, device=x.device)

        for t in range(L):
            h, c = self.cell(x[:, t], h, c)

        out = self.head(h)  # (B, 1, H, W)

        if TASK_TYPE == "binary":
            # raw logits, because BCEWithLogitsLoss expects logits
            return out

        elif TASK_TYPE == "regression":
            # unbounded output for ID / OD values
            return out

        elif TASK_TYPE == "CC_regression":
            # bounded output for CC prediction in [0,1]
            return torch.sigmoid(out)

# %% [markdown]
# ## Define the type of model and data

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

train_ds = NumpySeqDataset(X_train_n, y_train_p)
val_ds   = NumpySeqDataset(X_val_n, y_val_p)
test_ds  = NumpySeqDataset(X_test_n, y_test_p)

train_loader = DataLoader(train_ds, batch_size=8, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=8, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=8, shuffle=False)


# pos_weight = (#neg / #pos) over training pixels
pos = float(y_train_p.sum())
neg = float(y_train_p.size - y_train_p.sum())
pos_weight = torch.tensor([neg / (pos + 1e-6)], device=device)

if TASK_TYPE == "binary":
    model = ConvLSTM(
    input_dim=len(COEFFS),
    hidden_dim=32,
    kernel_size=3
        ).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

elif TASK_TYPE == "CC_regression":
    model = ConvLSTM(
    input_dim=X_train_n.shape[2],
    hidden_dim=32,
    kernel_size=3
        ).to(device)
    criterion = nn.MSELoss()

elif TASK_TYPE == "regression":   # for ID / OD
    model = ConvLSTM(
        input_dim=X_train_n.shape[2],
        hidden_dim=32,
        kernel_size=3,
    ).to(device)
    # criterion = nn.MSELoss()   # or SmoothL1Loss later
    criterion = nn.SmoothL1Loss()



opt = torch.optim.Adam(model.parameters(), lr=1e-3)

def evaluate(loader):
    model.eval()
    losses = []
    with torch.no_grad():
        for Xb, yb in loader:
            Xb, yb = Xb.to(device), yb.to(device)
            logits = model(Xb) # for regression it should be preds 
            loss = criterion(logits, yb)
            losses.append(loss.item())
    return float(np.mean(losses))

# %% [markdown]
# ## Training

# %%
for epoch in range(1, 11):
    model.train()
    for Xb, yb in train_loader:
        Xb, yb = Xb.to(device), yb.to(device)
        opt.zero_grad()
        logits = model(Xb) # for regression it should be preds
        loss = criterion(logits, yb)
        loss.backward()
        opt.step()

    val_loss = evaluate(val_loader)
    print(f"Epoch {epoch:02d} | val_loss={val_loss:.4f}")
# Out:
# Epoch 01 | val_loss=0.0000
# Epoch 02 | val_loss=0.0000
# Epoch 03 | val_loss=0.0000
# Epoch 04 | val_loss=0.0000
# Epoch 05 | val_loss=0.0000
# Epoch 06 | val_loss=0.0000
# Epoch 07 | val_loss=0.0000
# Epoch 08 | val_loss=0.0000
# Epoch 09 | val_loss=0.0000
# Epoch 10 | val_loss=0.0000

# %% [markdown]
# ## Evaluation metrics

# %%
def get_preds_and_targets(model, loader, device, apply_sigmoid=True):
    """
    Returns:
        pred_prob: (N, 1, H, W)
        true:      (N, 1, H, W)
    """
    model.eval()
    all_pred = []
    all_true = []

    with torch.no_grad():
        for Xb, yb in loader:
            Xb = Xb.to(device)
            logits = model(Xb)

            if apply_sigmoid:
                probs = torch.sigmoid(logits).cpu().numpy()
            else:
                probs = logits.cpu().numpy()

            all_pred.append(probs)
            all_true.append(yb.numpy())

    pred_prob = np.concatenate(all_pred, axis=0)
    true = np.concatenate(all_true, axis=0)
    return pred_prob, true


def compute_binary_metrics(y_true_bin, y_pred_bin, y_prob):
    """
    Inputs are flattened 1D arrays.
    """
    f1 = f1_score(y_true_bin, y_pred_bin, zero_division=0)
    precision = precision_score(y_true_bin, y_pred_bin, zero_division=0)
    recall = recall_score(y_true_bin, y_pred_bin, zero_division=0)

    intersection = np.logical_and(y_true_bin, y_pred_bin).sum()
    union = np.logical_or(y_true_bin, y_pred_bin).sum()
    iou = intersection / (union + 1e-6)

    pr_auc = average_precision_score(y_true_bin, y_prob)

    # ROC-AUC can fail if only one class is present
    
    roc_auc = roc_auc_score(y_true_bin, y_prob)

    # tn = np.logical_and(y_true_bin == 0, y_pred_bin == 0).sum()      
    # fp = np.logical_and(y_true_bin == 0, y_pred_bin == 1).sum()
    # specificity = tn / (tn + fp + 1e-6)

    brier = np.mean((y_prob - y_true_bin) ** 2)

    return {
        "f1": float(f1),
        "precision": float(precision),
        "recall": float(recall),
        "iou": float(iou),
        "pr_auc": float(pr_auc),
        "roc_auc": float(roc_auc) if not np.isnan(roc_auc) else np.nan,
        "brier": float(brier),
    }

def compute_non_binary_metrics(y_true_bin, y_prob):
    """
    For metrics that don't require a binary threshold (e.g. ROC-AUC, PR-AUC, Brier).
    """
    rmse = np.sqrt(np.mean((y_prob - y_true_bin) ** 2))
    r_squared = 1 - np.sum((y_true_bin - y_prob) ** 2) / np.sum((y_true_bin - np.mean(y_true_bin)) ** 2)
    mae = np.mean(np.abs(y_prob - y_true_bin))
    pearson_corr = np.corrcoef(y_true_bin, y_prob)[0, 1]

    return {
        "rmse": float(rmse),
        "r_squared": float(r_squared),
        "mae": float(mae),
        "pearson_corr": float(pearson_corr),
    }

# def compute_non_binary_metrics(y_true, y_pred):
#     rmse = np.sqrt(np.mean((y_pred - y_true) ** 2))
#     mae = np.mean(np.abs(y_pred - y_true))

#     denom = np.sum((y_true - np.mean(y_true)) ** 2)
#     if denom < 1e-12:
#         r_squared = np.nan
#     else:
#         r_squared = 1 - np.sum((y_true - y_pred) ** 2) / denom

#     if np.std(y_true) < 1e-12 or np.std(y_pred) < 1e-12:
#         pearson_corr = np.nan
#     else:
#         pearson_corr = np.corrcoef(y_true, y_pred)[0, 1]

#     return {
#         "rmse": float(rmse),
#         "r_squared": float(r_squared) if not np.isnan(r_squared) else np.nan,
#         "mae": float(mae),
#         "pearson_corr": float(pearson_corr) if not np.isnan(pearson_corr) else np.nan,
#     }

# %% [markdown]
# ## Find best threshold for each model

# %%
def find_best_threshold(y_true, y_prob, metric="f1", thresholds=None):
    """
    y_true: original target array, shape (N, 1, H, W) or similar
    y_prob: predicted probabilities, same shape
    """
    if thresholds is None:
        thresholds = np.linspace(0.05, 0.95, 91)

    y_true_bin = (y_true >= 0.5).astype(np.uint8).ravel()
    y_prob_flat = y_prob.ravel()

    best_thr = None
    best_score = -np.inf
    best_metrics = None

    for thr in thresholds:
        y_pred_bin = (y_prob_flat >= thr).astype(np.uint8)
        metrics = compute_binary_metrics(y_true_bin, y_pred_bin, y_prob_flat)
     

        score = metrics[metric]
        if score > best_score:
            best_score = score
            best_thr = float(thr)
            best_metrics = metrics

    return best_thr, best_score, best_metrics

# %% [markdown]
# #### It is important to find the best threshold, since the dataset is very imbalanced, mostly it is background pixels, not heatwave ones. The threshold tuning just converts that ranking into a better binary mask.

# %%
def evaluate_experiment(
    model,
    val_loader,
    test_loader,
    device,
    experiment_name,
    input_features,
    target_name,
    threshold_metric="f1",
):
    # ---------------------------------
    # decide automatically how to postprocess model outputs
    # ---------------------------------
    if TASK_TYPE == "binary":
        apply_sigmoid = True   # model returns logits
    else:
        apply_sigmoid = False  # regression models should already return final values

    # ---------------------------------
    # get predictions
    # ---------------------------------
    val_pred, val_true = get_preds_and_targets(model, val_loader, device, apply_sigmoid=apply_sigmoid)
    test_pred, test_true = get_preds_and_targets(model, test_loader, device, apply_sigmoid=apply_sigmoid)

    # =================================
    # BINARY TASK
    # =================================
    if TASK_TYPE == "binary":
        best_thr, best_val_score, val_metrics_at_best = find_best_threshold(
            val_true, val_pred, metric=threshold_metric
        )

        y_true = (test_true >= 0.5).astype(np.uint8).ravel()
        y_prob = test_pred.ravel()
        y_pred = (y_prob >= best_thr).astype(np.uint8)

        test_metrics = compute_binary_metrics(y_true, y_pred, y_prob)

        result = {
            "experiment": experiment_name,
            "inputs": ", ".join(input_features) if isinstance(input_features, (list, tuple)) else str(input_features),
            "target": target_name,
            "task_type": TASK_TYPE,
            "threshold_metric": threshold_metric,
            "best_val_threshold": float(best_thr),
            f"best_val_{threshold_metric}": float(best_val_score),

            "val_f1": val_metrics_at_best["f1"],
            "val_iou": val_metrics_at_best["iou"],
            "val_precision": val_metrics_at_best["precision"],
            "val_recall": val_metrics_at_best["recall"],
            "val_pr_auc": val_metrics_at_best["pr_auc"],
            "val_roc_auc": val_metrics_at_best["roc_auc"],
            "val_brier": val_metrics_at_best["brier"],

            "test_f1": test_metrics["f1"],
            "test_iou": test_metrics["iou"],
            "test_precision": test_metrics["precision"],
            "test_recall": test_metrics["recall"],
            "test_pr_auc": test_metrics["pr_auc"],
            "test_roc_auc": test_metrics["roc_auc"],
            "test_brier": test_metrics["brier"],
        }

        return result, test_pred, test_true, best_thr

    # =================================
    # REGRESSION TASKS: CC and ID / OD
    # =================================
    else:
        y_val_true = val_true.ravel()
        y_val_pred = val_pred.ravel()

        y_test_true = test_true.ravel()
        y_test_pred = test_pred.ravel()

        # For ID / OD regression, convert back from log-space
        if TASK_TYPE == "regression":
            y_val_true_eval = np.expm1(y_val_true)
            # y_val_pred_eval = np.expm1(y_val_pred)

            y_test_true_eval = np.expm1(y_test_true)
            # y_test_pred_eval = np.expm1(y_test_pred)

            y_val_pred_eval = np.maximum(np.expm1(y_val_pred), 0.0)
            y_test_pred_eval = np.maximum(np.expm1(y_test_pred), 0.0)

        # For CC regression, use outputs directly
        elif TASK_TYPE == "CC_regression":
            y_val_true_eval = y_val_true
            y_val_pred_eval = y_val_pred

            y_test_true_eval = y_test_true
            y_test_pred_eval = y_test_pred

        val_metrics = compute_non_binary_metrics(y_val_true_eval, y_val_pred_eval)
        test_metrics = compute_non_binary_metrics(y_test_true_eval, y_test_pred_eval)

        result = {
            "experiment": experiment_name,
            "inputs": ", ".join(input_features) if isinstance(input_features, (list, tuple)) else str(input_features),
            "target": target_name,
            "task_type": TASK_TYPE,

            "val_rmse": val_metrics["rmse"],
            "val_r_squared": val_metrics["r_squared"],
            "val_mae": val_metrics["mae"],
            "val_pearson_corr": val_metrics["pearson_corr"],

            "test_rmse": test_metrics["rmse"],
            "test_r_squared": test_metrics["r_squared"],
            "test_mae": test_metrics["mae"],
            "test_pearson_corr": test_metrics["pearson_corr"],
        }

        return result, y_test_pred_eval.reshape(test_pred.shape), y_test_true_eval.reshape(test_true.shape), None

# %%
def append_result_to_csv(result_dict, csv_path="ablation_results.csv"):
    df_new = pd.DataFrame([result_dict])

    if os.path.exists(csv_path):
        df_old = pd.read_csv(csv_path)
        df_all = pd.concat([df_old, df_new], ignore_index=True)
    else:
        df_all = df_new

    df_all.to_csv(csv_path, index=False)
    return df_all

# %%
# example names
experiment_name = "dc_cc_id_od_hw_to_bc" # change experiment name for each run to keep track of different ablations
input_features = COEFFS # change input features description based on the ablation (e.g. if you remove some coeffs, update this list accordingly)
target_name = TARGET  # change target name if you change the target variable in the dataset (e.g. if you switch to regression and predict CC, update this accordingly)

result, pred, true, best_thr = evaluate_experiment(
    model=model,
    val_loader=val_loader,
    test_loader=test_loader,
    device=device,
    experiment_name=experiment_name,
    input_features=input_features,
    target_name=target_name,
    threshold_metric="f1",
)

print(result)

df_all = append_result_to_csv(result, csv_path="ablation_results.csv")
print(df_all.tail())
# Out:
# {'experiment': 'dc_cc_id_od_hw_to_bc', 'inputs': 'CC, DC, ID, OD, is_heatwave', 'target': 'BC', 'task_type': 'regression', 'val_rmse': 0.0008914218051359057, 'val_r_squared': -356188.625, 'val_mae': 0.00035081052919849753, 'val_pearson_corr': 0.10887253402327424, 'test_rmse': 0.0014717356534674764, 'test_r_squared': -216865.46875, 'test_mae': 0.0006344098364934325, 'test_pearson_corr': 0.2755711462741843}
#                             experiment                           inputs  \
# 12                    all_coeffs_to_cc  CC, BC, DC, ID, OD, is_heatwave
# 13                    all_coeffs_to_od  CC, BC, DC, ID, OD, is_heatwave
# 14                    all_coeffs_to_bc  CC, BC, DC, ID, OD, is_heatwave
# 15  dc_bc_id_od_hw_to_cc_mediterranean      BC, DC, ID, OD, is_heatwave
# 16                dc_cc_id_od_hw_to_bc      CC, DC, ID, OD, is_heatwave
#
#    target threshold_metric  best_val_threshold  best_val_f1  val_f1  val_iou  \
# 12     CC              NaN                 NaN          NaN     NaN      NaN
# 13     OD              NaN                 NaN          NaN     NaN      NaN
# 14     BC              NaN                 NaN          NaN     NaN      NaN
# 15     CC              NaN                 NaN          NaN     NaN      NaN
# 16     BC              NaN                 NaN          NaN     NaN      NaN
#
#     val_precision  val_recall  ...  test_brier      task_type    val_rmse  \
# 12            NaN         NaN  ...         NaN  CC_regression    0.245910
# 13            NaN         NaN  ...         NaN     regression  491.632690
# 14            NaN         NaN  ...         NaN     regression    0.001024
# 15            NaN         NaN  ...         NaN  CC_regression    0.218468
# 16            NaN         NaN  ...         NaN     regression    0.000891
#
#     val_r_squared     val_mae  val_pearson_corr   test_rmse  test_r_squared  \
# 12       0.495612    0.110702          0.706471    0.255571        0.641996
# 13       0.078522  116.346245          0.454432  545.878418        0.058555
# 14 -469977.843750    0.000325          0.135932    0.001555  -242013.015625
# 15       0.543240    0.100633          0.737356    0.248443        0.583354
# 16 -356188.625000    0.000351          0.108873    0.001472  -216865.468750
#
#       test_mae  test_pearson_corr
# 12    0.128100           0.807881
# 13  157.361252           0.422344
# 14    0.000497           0.155260
# 15    0.115940           0.766814
# 16    0.000634           0.275571
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Visualise the predictions

# %% [markdown]
# ### 27.07.2003

# %%
# Find index of target date
target_date = np.datetime64("2003-07-27")
idx = np.where(test_dates == target_date)[0][0]

pred_map = pred[idx, 0]   # prediction map
true_map = true[idx, 0]   # true target map

lats = y_ib.lat.values
lons = y_ib.lon.values

def plot_mask_lonlat(mask, title):
    plt.figure()
    plt.pcolormesh(lons, lats, mask, shading="auto")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.colorbar()
    plt.show()

if TASK_TYPE == "binary":
    prob_map = pred_map
    bin_map = (prob_map >= best_thr).astype(int)
    err_map = bin_map - true_map

    plot_mask_lonlat(true_map, f"True heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(bin_map, f"Predicted heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(prob_map, f"Predicted probability (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) (Iberia) - {str(target_date)}")

elif TASK_TYPE == "CC_regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) CC (Iberia) - {str(target_date)}")

elif TASK_TYPE == "regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) BC (Iberia) - {str(target_date)}")

# %% [markdown]
# ### 1.08.2003

# %%
# Find index of target date
target_date = np.datetime64("2003-08-01")
idx = np.where(test_dates == target_date)[0][0]

pred_map = pred[idx, 0]   # prediction map
true_map = true[idx, 0]   # true target map

lats = y_ib.lat.values
lons = y_ib.lon.values

def plot_mask_lonlat(mask, title):
    plt.figure()
    plt.pcolormesh(lons, lats, mask, shading="auto")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.colorbar()
    plt.show()

if TASK_TYPE == "binary":
    prob_map = pred_map
    bin_map = (prob_map >= best_thr).astype(int)
    err_map = bin_map - true_map

    plot_mask_lonlat(true_map, f"True heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(bin_map, f"Predicted heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(prob_map, f"Predicted probability (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) (Iberia) - {str(target_date)}")

elif TASK_TYPE == "CC_regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) CC (Iberia) - {str(target_date)}")

elif TASK_TYPE == "regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) BC (Iberia) - {str(target_date)}")

# %% [markdown]
# ### 5.08.2003

# %%
# Find index of target date
target_date = np.datetime64("2003-08-05")
idx = np.where(test_dates == target_date)[0][0]

pred_map = pred[idx, 0]   # prediction map
true_map = true[idx, 0]   # true target map

lats = y_ib.lat.values
lons = y_ib.lon.values

def plot_mask_lonlat(mask, title):
    plt.figure()
    plt.pcolormesh(lons, lats, mask, shading="auto")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.colorbar()
    plt.show()

if TASK_TYPE == "binary":
    prob_map = pred_map
    bin_map = (prob_map >= best_thr).astype(int)
    err_map = bin_map - true_map

    plot_mask_lonlat(true_map, f"True heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(bin_map, f"Predicted heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(prob_map, f"Predicted probability (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) (Iberia) - {str(target_date)}")

elif TASK_TYPE == "CC_regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) CC (Iberia) - {str(target_date)}")

elif TASK_TYPE == "regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) BC (Iberia) - {str(target_date)}")

# %% [markdown]
# ### 10.08.2003

# %%
# Find index of target date
target_date = np.datetime64("2003-08-10")
idx = np.where(test_dates == target_date)[0][0]

pred_map = pred[idx, 0]   # prediction map
true_map = true[idx, 0]   # true target map

lats = y_ib.lat.values
lons = y_ib.lon.values

def plot_mask_lonlat(mask, title):
    plt.figure()
    plt.pcolormesh(lons, lats, mask, shading="auto")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.colorbar()
    plt.show()

if TASK_TYPE == "binary":
    prob_map = pred_map
    bin_map = (prob_map >= best_thr).astype(int)
    err_map = bin_map - true_map

    plot_mask_lonlat(true_map, f"True heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(bin_map, f"Predicted heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(prob_map, f"Predicted probability (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) (Iberia) - {str(target_date)}")

elif TASK_TYPE == "CC_regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) CC (Iberia) - {str(target_date)}")

elif TASK_TYPE == "regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) BC (Iberia) - {str(target_date)}")

# %% [markdown]
# ### 15.08.2003

# %%
# Find index of target date
target_date = np.datetime64("2003-08-15")
idx = np.where(test_dates == target_date)[0][0]

pred_map = pred[idx, 0]   # prediction map
true_map = true[idx, 0]   # true target map

lats = y_ib.lat.values
lons = y_ib.lon.values

def plot_mask_lonlat(mask, title):
    plt.figure()
    plt.pcolormesh(lons, lats, mask, shading="auto")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.colorbar()
    plt.show()

if TASK_TYPE == "binary":
    prob_map = pred_map
    bin_map = (prob_map >= best_thr).astype(int)
    err_map = bin_map - true_map

    plot_mask_lonlat(true_map, f"True heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(bin_map, f"Predicted heatwave mask (Iberia) - {str(target_date)}")
    plot_mask_lonlat(prob_map, f"Predicted probability (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) (Iberia) - {str(target_date)}")

elif TASK_TYPE == "CC_regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted CC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) CC (Iberia) - {str(target_date)}")

elif TASK_TYPE == "regression":
    err_map = pred_map - true_map

    plot_mask_lonlat(true_map, f"True BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(pred_map, f"Predicted BC map (Iberia) - {str(target_date)}")
    plot_mask_lonlat(err_map, f"Error map (Pred - True) BC (Iberia) - {str(target_date)}")

# %% [markdown]
# So given the past 14 days, the model predicts there is an (for example) 82% chance that tomorrow this location is in heatwave. IoU compares:
#
# Predicted region  ∩  True region / Predicted region  ∪  True region

# %% [markdown]
# ## Compare the results from the feature ablation (Predictors: 9 HW, 2 CC, 2 OD, 1 OD)

# %% [markdown]
# #### Binary classification - is_heatwave

# %%
import pandas as pd

df = pd.read_csv("ablation_results.csv")

df_bin = df[df["task_type"] == "binary"]
df_reg = df[df["task_type"] != "binary"]

best_bin = df_bin.sort_values("test_f1", ascending=False).head(5)
print(best_bin[["experiment", "inputs", "target", "test_f1", "test_pr_auc", "test_roc_auc"]])

best_reg = df_reg.sort_values("test_rmse", ascending=True).head(5)
print(best_reg[["experiment", "inputs", "target", "test_rmse", "test_r_squared", "test_pearson_corr"]])
# Out:
#              experiment                           inputs       target  \
# 2       all_coeff_to_hw  DC, BC, CC, ID, OD, is_heatwave  is_heatwave
# 5     dc_cc_id_od_to_hw                   DC, CC, ID, OD  is_heatwave
# 6     bc_cc_id_od_to_hw                   BC, CC, ID, OD  is_heatwave
# 8     bc_dc_cc_od_to_hw                   BC, DC, CC, OD  is_heatwave
# 4  bc_dc_cc_id_od_to_hw               DC, BC, CC, ID, OD  is_heatwave
#
#     test_f1  test_pr_auc  test_roc_auc
# 2  0.774061     0.792008      0.885346
# 5  0.759401     0.749586      0.868565
# 6  0.755370     0.742459      0.863400
# 8  0.749158     0.775292      0.877777
# 4  0.748148     0.747609      0.865421
#                             experiment                           inputs  \
# 16                dc_cc_id_od_hw_to_bc      CC, DC, ID, OD, is_heatwave
# 14                    all_coeffs_to_bc  CC, BC, DC, ID, OD, is_heatwave
# 15  dc_bc_id_od_hw_to_cc_mediterranean      BC, DC, ID, OD, is_heatwave
# 12                    all_coeffs_to_cc  CC, BC, DC, ID, OD, is_heatwave
# 3                 bc_dc_od_id_hw_to_cc      DC, BC, ID, OD, is_heatwave
#
#    target  test_rmse  test_r_squared  test_pearson_corr
# 16     BC   0.001472  -216865.468750           0.275571
# 14     BC   0.001555  -242013.015625           0.155260
# 15     CC   0.248443        0.583354           0.766814
# 12     CC   0.255571        0.641996           0.807881
# 3      CC   0.256766        0.638642           0.807655

# %%
import matplotlib.pyplot as plt

top = df_bin.sort_values("test_f1", ascending=False).head(10)

plt.figure()
plt.barh(top["experiment"], top["test_f1"])
plt.xlabel("Test F1")
plt.ylabel("Experiment")
plt.title("Top 10 Binary Experiments")
plt.gca().invert_yaxis()
plt.show()

# %%
grouped = df_bin.groupby("inputs")["test_f1"].mean().sort_values(ascending=False)
print(grouped.head(10))
# Out:
# inputs
# DC, BC, CC, ID, OD, is_heatwave    0.774061
# DC, CC, ID, OD                     0.759401
# BC, CC, ID, OD                     0.755370
# BC, DC, CC, OD                     0.749158
# DC, BC, CC, ID, OD                 0.748148
# OD, ID                             0.729836
# BC, DC, ID, OD                     0.729238
# BC, DC, CC, ID                     0.695768
# CC                                 0.542638
# Name: test_f1, dtype: float64

# %%
pivot = df.pivot_table(
    index="inputs",
    columns="target",
    values="test_f1"
)

print(pivot)
# Out:
# target                           is_heatwave
# inputs
# BC, CC, ID, OD                      0.755370
# BC, DC, CC, ID                      0.695768
# BC, DC, CC, OD                      0.749158
# BC, DC, ID, OD                      0.729238
# CC                                  0.542638
# DC, BC, CC, ID, OD                  0.748148
# DC, BC, CC, ID, OD, is_heatwave     0.774061
# DC, CC, ID, OD                      0.759401
# OD, ID                              0.729836

# %%
best = df_bin.loc[df_bin["test_f1"].idxmax()]

print("\nBEST EXPERIMENT:")
print(best)
# Out:
# BEST EXPERIMENT:
# experiment                            all_coeff_to_hw
# inputs                DC, BC, CC, ID, OD, is_heatwave
# target                                    is_heatwave
# threshold_metric                                   f1
# best_val_threshold                               0.74
# best_val_f1                                  0.602221
# val_f1                                       0.602221
# val_iou                                      0.430841
# val_precision                                0.567804
# val_recall                                   0.641079
# val_pr_auc                                   0.638527
# val_roc_auc                                  0.863771
# val_brier                                    0.162087
# test_f1                                      0.774061
# test_iou                                     0.631403
# test_precision                               0.752505
# test_recall                                  0.796889
# test_pr_auc                                  0.792008
# test_roc_auc                                 0.885346
# test_brier                                   0.157799
# task_type                                      binary
# val_rmse                                          NaN
# val_r_squared                                     NaN
# val_mae                                           NaN
# val_pearson_corr                                  NaN
# test_rmse                                         NaN
# test_r_squared                                    NaN
# test_mae                                          NaN
# test_pearson_corr                                 NaN
# Name: 2, dtype: object

# %%
import matplotlib.pyplot as plt

pivot = df_bin.pivot_table(
    index="inputs",
    columns="target",
    values="test_f1"
)

plt.figure()
plt.imshow(pivot, aspect="auto")
plt.xticks(range(len(pivot.columns)), pivot.columns, rotation=45)
plt.yticks(range(len(pivot.index)), pivot.index)
plt.colorbar(label="Test F1")
plt.title("Ablation Heatmap (Binary)")
plt.show()

# %% [markdown]
# ### Regression

# %%
import pandas as pd

reg = df_reg.copy()

# Metrics where LOWER is better
for col in ["test_rmse", "test_mae"]:
    reg[col + "_norm"] = (reg[col] - reg[col].min()) / (reg[col].max() - reg[col].min())

# Metrics where HIGHER is better
for col in ["test_r_squared", "test_pearson_corr"]:
    reg[col + "_norm"] = (reg[col].max() - reg[col]) / (reg[col].max() - reg[col].min())

# %%
reg["overall_score"] = (
    reg["test_rmse_norm"] +
    reg["test_mae_norm"] +
    reg["test_r_squared_norm"] +
    reg["test_pearson_corr_norm"]
)

# %%
best_reg = reg.sort_values("overall_score").head(10)

print(best_reg[[
    "experiment", "inputs", "target",
    "test_rmse", "test_mae",
    "test_r_squared", "test_pearson_corr"
]])
# Out:
#                             experiment                           inputs  \
# 12                    all_coeffs_to_cc  CC, BC, DC, ID, OD, is_heatwave
# 3                 bc_dc_od_id_hw_to_cc      DC, BC, ID, OD, is_heatwave
# 15  dc_bc_id_od_hw_to_cc_mediterranean      BC, DC, ID, OD, is_heatwave
# 16                dc_cc_id_od_hw_to_bc      CC, DC, ID, OD, is_heatwave
# 1                    dc_bc_cc_hw_to_od          DC, BC, CC, is_heatwave
# 14                    all_coeffs_to_bc  CC, BC, DC, ID, OD, is_heatwave
# 13                    all_coeffs_to_od  CC, BC, DC, ID, OD, is_heatwave
# 0                    dc_bc_cc_hw_to_id          DC, BC, CC, is_heatwave
#
#    target   test_rmse    test_mae  test_r_squared  test_pearson_corr
# 12     CC    0.255571    0.128100        0.641996           0.807881
# 3      CC    0.256766    0.135876        0.638642           0.807655
# 15     CC    0.248443    0.115940        0.583354           0.766814
# 16     BC    0.001472    0.000634  -216865.468750           0.275571
# 1      OD  528.981201  151.459763        0.115936           0.432487
# 14     BC    0.001555    0.000497  -242013.015625           0.155260
# 13     OD  545.878418  157.361252        0.058555           0.422344
# 0      ID  736.870972  214.783478       -0.053587           0.153255

# %%
top = df_reg.sort_values("test_rmse").head(5)

metrics = ["test_rmse", "test_mae", "test_r_squared", "test_pearson_corr"]

for _, row in top.iterrows():
    print("\n---", row["experiment"], "---")
    for m in metrics:
        print(f"{m}: {row[m]:.4f}")
# Out:
# --- dc_cc_id_od_hw_to_bc ---
# test_rmse: 0.0015
# test_mae: 0.0006
# test_r_squared: -216865.4688
# test_pearson_corr: 0.2756
#
# --- all_coeffs_to_bc ---
# test_rmse: 0.0016
# test_mae: 0.0005
# test_r_squared: -242013.0156
# test_pearson_corr: 0.1553
#
# --- dc_bc_id_od_hw_to_cc_mediterranean ---
# test_rmse: 0.2484
# test_mae: 0.1159
# test_r_squared: 0.5834
# test_pearson_corr: 0.7668
#
# --- all_coeffs_to_cc ---
# test_rmse: 0.2556
# test_mae: 0.1281
# test_r_squared: 0.6420
# test_pearson_corr: 0.8079
#
# --- bc_dc_od_id_hw_to_cc ---
# test_rmse: 0.2568
# test_mae: 0.1359
# test_r_squared: 0.6386
# test_pearson_corr: 0.8077

# %%
top = df_reg.sort_values("test_rmse").head(5)

plt.figure()

for metric in ["test_rmse", "test_mae"]:
    plt.plot(top["experiment"], top[metric], label=metric)

plt.legend()
plt.xticks(rotation=45)
plt.title("Regression Metrics Comparison")
plt.show()

# %% [markdown]
# #### Regression - CC, ID, OD

# %%
top = df_reg.sort_values("test_rmse").head(10)

plt.figure()
plt.barh(top["experiment"], top["test_rmse"])
plt.xlabel("Test RMSE")
plt.ylabel("Experiment")
plt.title("Top 10 Regression Experiments")
plt.gca().invert_yaxis()
plt.show()

# %%
top = df_reg.sort_values("test_mae", ascending=False).head(10)

plt.figure()
plt.barh(top["experiment"], top["test_mae"])
plt.xlabel("Test MAE")
plt.ylabel("Experiment")
plt.title("Top 10 Regression Experiments")
plt.gca().invert_yaxis()
plt.show()

# %%
top = df_reg.sort_values("test_pearson_corr", ascending=False).head(10)

plt.figure()
plt.barh(top["experiment"], top["test_pearson_corr"])
plt.xlabel("Test Pearson Correlation")
plt.ylabel("Experiment")
plt.title("Top 10 Regression Experiments")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Can the model learn network structure evolution?

# %% [markdown]
# Degree Centrality (DC)
#
# How synchronized a region is with others.
#
# ➡ high = many regions experiencing heat together
# ➡ hubs of heatwave activity
#
# Clustering Coefficient (CC)
#
# Local clustering of heatwaves.
#
# ➡ high = localized heatwave cluster
# ➡ stationary behaviour
#
# Betweenness Centrality (BC)
#
# Propagation corridor importance.
#
# ➡ high = heatwave movement pathway
# ➡ dynamic propagation routes

# %% [markdown]
# Use CN metrics to:
#
# ✔ identify propagation corridors
# ✔ detect dynamic heatwaves
# ✔ validate DL trajectories
#
# Use is_heatwave to:
#
# ✔ define events
# ✔ train models
# ✔ detect movement
#
# Use E-OBS Tmax to:
#
# ✔ build sequences
# ✔ provide physical context
